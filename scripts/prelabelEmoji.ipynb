# %%
#Important Libraries
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import pickle
import emoji
import advertools as adv
warnings.simplefilter("ignore")

# %%
#Define Classes

#Positive Emojis
PosSent = [['😊'],['😃'],['😀'],['😉'],['😇'],['🥰'],['😍'],['🤩'],['😘'],['😗'],['😚'],
          ['😙'],['😋'],['😛'],['😜'],['🤑'],['🤗'],['🤓'],['😹'],['😻'],['😎'],['💝'],['💖'],['💕'],
           ['❤️'],['💯'],['👍'],['👏'],['🤝'],['🙏'],['💪'],['💀'],['🔥'],['🎊'],['🎉'],['🏆'],['🎯'],['📣'],
           ['🎼'],['🎤'],['💰'],['🌱'],['✈️'],['✅'],['☑️'],['✔️'],['✌️'],['🦾'],['🌻'],['🍑'],['🍆'],['🌽'],['🏢'],
           ['⭐'],['🌈'],['⚡'],['🎈'],['🤤']
          ]

#Negative Emojis
NegSent = [['😭'],['😞'],['😴'],['🤣'],['🙌'],['😂'],['🤕'],['🤒'],['😒'],['🙄'],['😬'],['😔'],['😪'],['🤢'],['🤮'],['🤧'],['🥴'],
           ['😵'],['😁'],
            ['🤯'],['😕'],['😢'],['😱'],['😤'],['💩'],['💔'],['👎'],['😅'],['😝'],['😏'],['🌚']
    ]

#Neutral Emojis
NeutSent = [['🙃'],['🤪'],['🤭'],['🙈'],['🙊'],['☎️'],['🤔'],['🤐'],['😶']
            ]

# %%
#Function for Detecting Emoticons and classifying
def emotidetect(text): 
    er = adv.extract_emoji(text)
    d=er['emoji']
    #remove empty list in list
    s = [x for x in d if x]
    #Select first item in list
    if s:
        ft =s[0]
        if ft in PosSent:
            Sent ='POS'
        elif ft in NegSent:
            Sent ='NEG'
        elif ft in NeutSent:
            Sent = 'NEU'
        elif ft:
            Sent='NEG'
    else :
        Sent ='UNK'
    return Sent

# %%
#Check detection
emotidetect(text3)
# Out:
# 'POS'

# %%
datasetA = pd.read_excel(r'excelfilewithemojis')

# %%
#Check dataset
datasetA.head(5)
# Out:
#             UserID           Date/Time         topic SearchTerm emoticonBased  \
# 0  michaeltanaka02 2022-09-25 13:25:33         Music    Shadaya           UNK
# 1         maurutsa 2022-09-19 00:47:01  Home_Affairs       Baba           UNK
# 2        Samaita_1 2022-09-25 16:54:06       Defence    chamisa           UNK
# 3          Irvman6 2022-09-18 18:38:12       Finance        uyu           UNK
# 4          kooodzy 2022-09-13 20:28:38   Sanitation       Vanhu           UNK
#
#   lexiconBased   lex LEX,EMOT LEX,EMOT.1 Annotation 1 Annotation 2  \
# 0          UNK  emot     emot       emot          NEG         VNEG
# 1          NEG   NEG      NEG        NEG          NEU         VNEG
# 2          POS   POS      POS        POS          POS         VPOS
# 3          POS   POS      POS        POS         VNEG          NEG
# 4          POS   POS      POS        POS         VNEG          NEU
#
#   Annotation 3 finalLabel5Classes finalLabel3Classes  \
# 0          NEG                NEG                NEG
# 1         VNEG               VNEG                NEG
# 2         VPOS               VPOS                POS
# 3         VNEG               VNEG                NEG
# 4          NEU                NEU                NEU
#
#                             SN(Original Shona Tweet)  \
# 0  @Tec01zw @magumbo_wacho Even Shadaya ari wrong...
# 1  @ShadayaKnight Baba Harare ngavaite zvezvigure...
# 2  @sedzejacob Chamisa, ane pfungwa itsva uye ano...
# 3  @KingJayZim Uyu kana asina kuromba akaromba ch...
# 4  @villageman263 Chero vakanzi Vakuridza mahara,...
#
#                                    ENGoogleTranslate
# 0  @Tec01zw @magumbo_wacho Even if Shadaya is wro...
# 1  @ShadayaKnight Baba Harare should do something...
# 2  @sedzejacob Chamisa, has a new idea and works ...
# 3  @KingJayZim This one, if he's not broke, he's ...
# 4  @villageman263 Even if they say they are playi...

# %%
#Detect Emotions
datasetA['EmoticonVersion9'] = datasetA['SN(Original Shona Tweet)'].apply(lambda x: emotidetect(x))
